# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('content/Day-76/apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.sample(5)
# Out:
#                                            App            Category  Rating  \
# 1501                                EP Spotter              FAMILY    3.40
# 4186               Restaurant Inspections - FL  HEALTH_AND_FITNESS    3.50
# 4019              WiseBanyan - Invest For Free             FINANCE    4.20
# 9153            Runkeeper - GPS Track Run Walk  HEALTH_AND_FITNESS    4.50
# 10744  Clean Master- Space Cleaner & Antivirus               TOOLS    4.70
#
#         Reviews  Size_MBs     Installs  Type Price Content_Rating  \
# 1501          9     28.00          500  Free     0       Everyone
# 4186        143      0.22       10,000  Free     0       Everyone
# 4019        257     44.00       10,000  Free     0       Everyone
# 9153     501144      8.80   10,000,000  Free     0       Everyone
# 10744  42916526      3.40  500,000,000  Free     0       Everyone
#
#                  Genres        Last_Updated         Android_Ver
# 1501      Entertainment  September 28, 2016          4.3 and up
# 4186   Health & Fitness       June 12, 2013          2.2 and up
# 4019            Finance       July 31, 2018         4.4W and up
# 9153   Health & Fitness       July 16, 2018  Varies with device
# 10744             Tools      August 3, 2018  Varies with device

# %%
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 0             0      8.70              0  Paid  $13.99           Teen
# 1             0     33.00              0  Paid   $2.99       Everyone
# 2             0      5.50              0  Paid   $1.49       Everyone
# 3             0     19.00              0   NaN       0   Everyone 10+
# 4             0     10.00              0  Free       0       Everyone
# ...         ...       ...            ...   ...     ...            ...
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10839  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres    Last_Updated         Android_Ver
# 0               Social   July 28, 2017          4.1 and up
# 1            Education  April 15, 2016          3.0 and up
# 2      Personalization   July 11, 2018          4.2 and up
# 3             Strategy   June 28, 2018  Varies with device
# 4             Business  August 6, 2018          4.1 and up
# ...                ...             ...                 ...
# 10836           Arcade   July 12, 2018          4.1 and up
# 10837           Arcade   July 12, 2018          4.1 and up
# 10838           Arcade   July 12, 2018          4.1 and up
# 10839           Arcade   July 12, 2018          4.1 and up
# 10840           Arcade   July 12, 2018          4.1 and up
#
# [10841 rows x 12 columns]

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=['Last_Updated', 'Android_Ver'], inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %%
df_apps_clean
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10839                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# 21            4     25.00              1  Free      0       Everyone  Medical
# 28            2     20.00              1  Paid  $1.49       Everyone   Arcade
# 47            2     16.00              1  Paid  $0.99       Everyone   Arcade
# 82            7     19.00              5  Free      0       Everyone   Arcade
# 99            1      4.60              5  Free      0       Everyone  Medical
# ...         ...       ...            ...   ...    ...            ...      ...
# 10836  27723193     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10837  27724094     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10838  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10839  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10840  27711703     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
#
# [9367 rows x 10 columns]

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# np.int64(476)

# %%
df_apps_clean[df_apps_clean['App'] == 'Instagram'].count()
# Out:
# App               4
# Category          4
# Rating            4
# Reviews           4
# Size_MBs          4
# Installs          4
# Type              4
# Price             4
# Content_Rating    4
# Genres            4
# dtype: int64

# %%
df_apps_clean.drop_duplicates(inplace=True)
df_apps_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_apps_clean[df_apps_clean["App"].duplicated(keep=False)]
# Out:
#                                               App   Category  Rating  \
# 1195   Cardiac diagnosis (heart rate, arrhythmia)    MEDICAL    4.40
# 2517       Fuzzy Numbers: Pre-K Number Foundation  EDUCATION    4.70
# 2520       Fuzzy Numbers: Pre-K Number Foundation     FAMILY    4.70
# 2637                                   Calculator     DATING    2.60
# 3060                Manga AZ - Manga Comic Reader     COMICS    3.30
# ...                                           ...        ...     ...
# 10835                              Subway Surfers       GAME    4.50
# 10836                              Subway Surfers       GAME    4.50
# 10837                              Subway Surfers       GAME    4.50
# 10838                              Subway Surfers       GAME    4.50
# 10840                              Subway Surfers       GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 1195          8      6.50            100  Paid  $12.99       Everyone
# 2517         21     44.00          1,000  Paid   $5.99       Everyone
# 2520         21     44.00          1,000  Paid   $5.99       Everyone
# 2637         57      6.20          1,000  Paid   $6.99       Everyone
# 3060        125      4.70          5,000  Free       0           Teen
# ...         ...       ...            ...   ...     ...            ...
# 10835  27722264     76.00  1,000,000,000  Free       0   Everyone 10+
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                     Genres
# 1195               Medical
# 2517   Education;Education
# 2520   Education;Education
# 2637                Dating
# 3060                Comics
# ...                    ...
# 10835               Arcade
# 10836               Arcade
# 10837               Arcade
# 10838               Arcade
# 10840               Arcade
#
# [1213 rows x 10 columns]

# %%
df_apps_clean['App'].duplicated().sum()
# Out:
# np.int64(694)

# %%
df_apps_clean = (
    df_apps_clean
    .sort_values("Reviews", ascending=False)
    .drop_duplicates(subset="App", keep="first")
)
df_apps_clean["App"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_apps_clean
# Out:
#                                             App            Category  Rating  \
# 10805                                  Facebook              SOCIAL    4.10
# 10785                        WhatsApp Messenger       COMMUNICATION    4.40
# 10808                                 Instagram              SOCIAL    4.50
# 10790  Messenger – Text and Video Chat for Free       COMMUNICATION    4.00
# 10652                            Clash of Clans                GAME    4.60
# ...                                         ...                 ...     ...
# 576                               Clarksburg AH             MEDICAL    1.00
# 582                                       MI-BP  HEALTH_AND_FITNESS    5.00
# 617                              DT future1 cam               TOOLS    1.00
# 677                                 CT Checkout             FINANCE    5.00
# 1451                  Android P Style Icon Pack     PERSONALIZATION    5.00
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free      0           Teen
# 10785  69119316      3.50  1,000,000,000  Free      0       Everyone
# 10808  66577446      5.30  1,000,000,000  Free      0           Teen
# 10790  56646578      3.50  1,000,000,000  Free      0       Everyone
# 10652  44893888     98.00    100,000,000  Free      0   Everyone 10+
# ...         ...       ...            ...   ...    ...            ...
# 576           1     28.00             50  Free      0       Everyone
# 582           1     12.00             50  Free      0       Everyone
# 617           1     24.00             50  Free      0       Everyone
# 677           1      8.40             50  Free      0       Everyone
# 1451          1     60.00            100  Paid  $0.99       Everyone
#
#                  Genres
# 10805            Social
# 10785     Communication
# 10808            Social
# 10790     Communication
# 10652          Strategy
# ...                 ...
# 576             Medical
# 582    Health & Fitness
# 617               Tools
# 677             Finance
# 1451    Personalization
#
# [8197 rows x 10 columns]

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values(by='Rating', ascending=False)
df_apps_clean.head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10808                                 Instagram         SOCIAL    4.50
# 10790  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10652                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10808  66577446      5.30  1,000,000,000  Free     0           Teen
# 10790  56646578      3.50  1,000,000,000  Free     0       Everyone
# 10652  44893888     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10808         Social
# 10790  Communication
# 10652       Strategy

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean[df_apps_clean['Size_MBs'] == df_apps_clean['Size_MBs'].max()]
# Out:
#                                                     App            Category  \
# 10688                            Hungry Shark Evolution                GAME
# 10295                                   SimCity BuildIt              FAMILY
# 8718                  Mini Golf King - Multiplayer Game                GAME
# 9943                              Miami crime simulator                GAME
# 9945                                    Ultimate Tennis              SPORTS
# 8719                         Draft Simulator for FUT 18              SPORTS
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 9944                       Gangster Town: Vice District              FAMILY
# 7926                                          Post Bank             FINANCE
# 7928                      Stickman Legends: Shadow Wars                GAME
# 7927                        The Walking Dead: Our World                GAME
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 1795                               Navi Radiography Pro             MEDICAL
#
#        Rating  Reviews  Size_MBs     Installs  Type   Price Content_Rating  \
# 10688    4.50  6074627    100.00  100,000,000  Free       0           Teen
# 10295    4.50  4218587    100.00   50,000,000  Free       0   Everyone 10+
# 8718     4.50   531458    100.00    5,000,000  Free       0       Everyone
# 9943     4.00   254518    100.00   10,000,000  Free       0     Mature 17+
# 9945     4.30   183004    100.00   10,000,000  Free       0       Everyone
# 8719     4.60   162933    100.00    5,000,000  Free       0       Everyone
# 9942     4.00   140995    100.00   10,000,000  Free       0       Everyone
# 9944     4.30    65146    100.00   10,000,000  Free       0     Mature 17+
# 7926     4.50    60449    100.00    1,000,000  Free       0       Everyone
# 7928     4.40    38419    100.00    1,000,000  Paid   $0.99   Everyone 10+
# 7927     4.00    22435    100.00    1,000,000  Free       0           Teen
# 4176     3.60      151    100.00       10,000  Free       0       Everyone
# 3144     3.60      124    100.00        5,000  Free       0       Everyone
# 1795     4.70       11    100.00          500  Paid  $15.99       Everyone
#
#                        Genres
# 10688                  Arcade
# 10295              Simulation
# 8718                   Sports
# 9943                   Action
# 9945                   Sports
# 8719                   Sports
# 9942   Lifestyle;Pretend Play
# 9944               Simulation
# 7926                  Finance
# 7928                   Action
# 7927                   Action
# 4176                   Racing
# 3144         Health & Fitness
# 1795                  Medical

# %%
df_apps_clean.sort_values(by='Size_MBs', ascending=False).head()
# Out:
#                                     App   Category  Rating  Reviews  Size_MBs  \
# 1795               Navi Radiography Pro    MEDICAL    4.70       11    100.00
# 9944       Gangster Town: Vice District     FAMILY    4.30    65146    100.00
# 7926                          Post Bank    FINANCE    4.50    60449    100.00
# 9942     Talking Babsy Baby: Baby Games  LIFESTYLE    4.00   140995    100.00
# 8718  Mini Golf King - Multiplayer Game       GAME    4.50   531458    100.00
#
#         Installs  Type   Price Content_Rating                  Genres
# 1795         500  Paid  $15.99       Everyone                 Medical
# 9944  10,000,000  Free       0     Mature 17+              Simulation
# 7926   1,000,000  Free       0       Everyone                 Finance
# 9942  10,000,000  Free       0       Everyone  Lifestyle;Pretend Play
# 8718   5,000,000  Free       0       Everyone                  Sports

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10808                                 Instagram         SOCIAL    4.50
# 10790  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10652                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10808  66577446      5.30  1,000,000,000  Free     0           Teen
# 10790  56646578      3.50  1,000,000,000  Free     0       Everyone
# 10652  44893888     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10808         Social
# 10790  Communication
# 10652       Strategy

# %%
(
    df_apps_clean
    .sort_values(by='Reviews', ascending=False)
    .head(50)['Type']
    .eq('Paid')
    .any()
)
# Out:
# np.False_

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6619
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(labels=ratings.index,
             values=ratings.values,
             title="Content Rating",
             names=ratings.index,
             )
fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %%
fig = px.pie(labels=ratings.index,
             values=ratings.values,
             title="Content Rating",
             names=ratings.index,
             hole=0.4,
             )
fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8197 entries, 10805 to 1451
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8197 non-null   str
#  1   Category        8197 non-null   str
#  2   Rating          8197 non-null   float64
#  3   Reviews         8197 non-null   int64
#  4   Size_MBs        8197 non-null   float64
#  5   Installs        8197 non-null   str
#  6   Type            8197 non-null   str
#  7   Price           8197 non-null   str
#  8   Content_Rating  8197 non-null   str
#  9   Genres          8197 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 704.4 KB

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].str.replace(',', '')
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean.Installs.info()
# Out:
# <class 'pandas.Series'>
# Index: 8197 entries, 10805 to 1451
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 8197 non-null   int64
# dtypes: int64(1)
# memory usage: 128.1 KB

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].str.replace('$', '')
df_apps_clean['Price'] = df_apps_clean['Price'].astype(float)
df_apps_clean.Price.info()
# Out:
# <class 'pandas.Series'>
# Index: 8197 entries, 10805 to 1451
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 8197 non-null   float64
# dtypes: float64(1)
# memory usage: 128.1 KB

# %%
df_apps_clean['App'][df_apps_clean['Installs'] >= 1000000000].count()
# Out:
# np.int64(20)

# %%
installs = df_apps_clean[['App', 'Installs']].groupby('Installs').count()
installs
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          302
# 500          199
# 1000         697
# 5000         425
# 10000        986
# 50000        457
# 100000      1095
# 500000       503
# 1000000     1415
# 5000000      607
# 10000000     937
# 50000000     204
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
print(print(installs.index),
print(installs["App"]))
# Out:
# Index([         1,          5,         10,         50,        100,        500,
#              1000,       5000,      10000,      50000,     100000,     500000,
#           1000000,    5000000,   10000000,   50000000,  100000000,  500000000,
#        1000000000],
#       dtype='int64', name='Installs')
# Installs
# 1                3
# 5                9
# 10              69
# 50              56
# 100            302
# 500            199
# 1000           697
# 5000           425
# 10000          986
# 50000          457
# 100000        1095
# 500000         503
# 1000000       1415
# 5000000        607
# 10000000       937
# 50000000       204
# 100000000      189
# 500000000       24
# 1000000000      20
# Name: App, dtype: int64
# None None

# %%
installs_plot = installs.reset_index()
installs_plot["Installs"] = installs_plot["Installs"].astype(str)

fig = px.bar(
    installs_plot,
    x="App",
    y="Installs",
    orientation="h"
)

fig.update_yaxes(type="category")


fig.show()

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %% [markdown]
# ### The most expensive apps sub $250

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
